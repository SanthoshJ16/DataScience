# %%
from UnivariateAllFunctions import univariate
## Reading the data from CSV file
dataset=univariate.importDataset()

# %%
## Splitting the qual, quan data 
quan,qual = univariate.quanQual(dataset)

# %%
## Calling this function to retrieve univariate data's
descriptive=univariate.findUnivariate(dataset,quan)

# %%
## Calling this function to find the list of columns conting lower and higher outlier
lower,higher=univariate.checkforOutliers(descriptive,quan)
print(lower)
print(higher)
# Out:
# ['hsc_p']
# ['hsc_p', 'degree_p', 'salary']

# %%
## Calling this function to set/replace the dataset with lowerIQR and higherIQR for the Outliers
descriptive=univariate.replaceOutliersWithIQRValues(dataset,descriptive,lower,higher)

# %%
## Rerunning this function to retrieve univariate data's after clean up
descriptive=univariate.findUnivariate(dataset,quan)

# %%
## Rerunning this function to check for outliers again. 
## Note: this should return an empty lower and higher list 
# as the clean up is done in earlier step
lower,higher=univariate.checkforOutliers(descriptive,quan)
print(lower)
print(higher)
# Out:
# []
# []

# %%
## Calling this function to get the frequency Table for the input Column
freqTable=univariate.freqTable(dataset,"ssc_p")

# %%
## printing the frequency Table for verification
## commenting the table for now
## freqTable

# %%
descriptive
# Out:
#                  sl_no        ssc_p        hsc_p     degree_p      etest_p  \
# Mean             108.0    67.303395    66.334744    66.358558    72.100558
# Median           108.0         67.0         65.0         66.0         71.0
# Mode                 1         62.0         63.0         65.0         60.0
# Q1:25%            54.5         60.6         60.9         61.0         60.0
# Q2:50%           108.0         67.0         65.0         66.0         71.0
# Q3:75%           161.5         75.7         73.0         72.0         83.5
# Q4:100%          215.0         89.4        91.15         88.5         98.0
# IQR              107.0         15.1         12.1         11.0         23.5
# 1.5rule          160.5        22.65        18.15         16.5        35.25
# LowerIQR        -106.0        37.95        42.75         44.5        24.75
# HigherIQR        322.0        98.35        91.15         88.5       118.75
# ...

# %%
descriptive
# Out:
#                  sl_no        ssc_p        hsc_p     degree_p      etest_p  \
# Mean             108.0    67.303395    66.334744    66.358558    72.100558
# Median           108.0         67.0         65.0         66.0         71.0
# Mode                 1         62.0         63.0         65.0         60.0
# Q1:25%            54.5         60.6         60.9         61.0         60.0
# Q2:50%           108.0         67.0         65.0         66.0         71.0
# Q3:75%           161.5         75.7         73.0         72.0         83.5
# Q4:100%          215.0         89.4        91.15         88.5         98.0
# IQR              107.0         15.1         12.1         11.0         23.5
# 1.5rule          160.5        22.65        18.15         16.5        35.25
# LowerIQR        -106.0        37.95        42.75         44.5        24.75
# HigherIQR        322.0        98.35        91.15         88.5       118.75
# ...
