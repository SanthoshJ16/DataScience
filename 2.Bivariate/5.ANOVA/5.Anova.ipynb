# %%
from BiVariateAllFunctions import bivariate as bivar
## Reading the data from CSV file
dataset=bivar.importDataset()

# %%
#dataset

# %% [markdown]
# ### Anova

# %%
import scipy.stats as stats
stats.f_oneway(dataset["ssc_p"],dataset["hsc_p"],dataset["degree_p"])
# Out:
# F_onewayResult(statistic=np.float64(0.695991304348204), pvalue=np.float64(0.49895574725815317))

# %%
## Problem Statement : Check whether the mean academic performance scores differ significantly among SSC, HSC, and Degree percentages.

# %%
## Null Hypothesis : There is no significant differnt in the performance between among SSC, HSC, and Degree percentages

# %%
## From the above Anova test results , we got a pvalue=0.498 which is higher than 0.05%

# %%
## Note : We reject Null hypothesis only if pvalue<0.05%

# %%
## Solution :We reject Null hypthesis since the pvalue is greater in this case

# %%
## Procees with Alternative hypothesis
