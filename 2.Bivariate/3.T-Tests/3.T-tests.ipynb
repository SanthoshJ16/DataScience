# %%
from BiVariateAllFunctions import bivariate as bivar
## Reading the data from CSV file
dataset=bivar.importDataset()

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Independant Sample - Unpaired T -Test

# %%
## Unpaired T test
## Different Group #Same condition 

from scipy.stats import ttest_ind
male = dataset[dataset['gender']=='M']['salary']
female = dataset[dataset['gender']=='F']['salary']
ttest_ind(male, female)
# Out:
# TtestResult(statistic=np.float64(2.0937842507001165), pvalue=np.float64(0.03746230397067219), df=np.float64(213.0))

# %% [markdown]
# # Dependant Sample - Paired T test

# %%
## Paired T test
## Same Group #different condition 

from scipy.stats import ttest_ind
male = dataset[dataset['gender']=='M']['hsc_p']
male1 = dataset[dataset['gender']=='M']['ssc_p']
ttest_ind(male, male1)
# Out:
# TtestResult(statistic=np.float64(-0.4609004016724563), pvalue=np.float64(0.6452330329980636), df=np.float64(276.0))

# %% [markdown]
# # Assigment - Unpaired T Test

# %%
## Different Group hsc_b(Others,Central) Same condition (Salary)

other = dataset[dataset['hsc_b']=='Others']['salary']
central = dataset[dataset['hsc_b']=='Central']['salary']
ttest_ind(other, central)

## The resulted p‑value 0.76 is much larger than 0.05 , higher P value indicates this could be just chance not real
# Out:
# TtestResult(statistic=np.float64(0.30570032095155825), pvalue=np.float64(0.7601313863865756), df=np.float64(213.0))

# %% [markdown]
# # Assigment - Paired T Test

# %%
## Paired T test
## Same Group (hsc_s)#different condition (etest_p,mba_p)

from scipy.stats import ttest_ind
etest_p = dataset[dataset['hsc_s']=='Commerce']['etest_p']
mba_p = dataset[dataset['hsc_s']=='Commerce']['mba_p']
ttest_ind(etest_p, mba_p)

## The resulted p‑value 1.84 is much larger than 0.05 , higher P value indicates this could be just chance not real
# Out:
# TtestResult(statistic=np.float64(7.079422262550767), pvalue=np.float64(1.844299454870846e-11), df=np.float64(224.0))
